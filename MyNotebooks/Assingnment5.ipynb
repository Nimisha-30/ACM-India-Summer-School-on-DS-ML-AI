# %%
f1_score(y_test, y_pred_nb, average=None)
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.15384615, 0.        , 0.        ,
#        0.42424242, 0.        , 0.        , 0.        , 0.        ,
#        0.09090909])

# %%
roc_nb=roc_auc_score(y_test, nbClassifier.predict_proba(x_test)[:, 1])
fpr_nb, tpr_nb, thresholds_nb=roc_curve(y_test, nbClassifier.predict_proba(x_test)[:, 1])
plt.plot(fpr_nb, tpr_nb, linewidth=2, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# %%
precisions_nb, recalls_nb, thresholds_nb=precision_recall_curve(y_test, nbClassifier.predict(x_test))
plt.plot(recalls_nb, precisions_nb, label='Precision/Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision') 
plt.show()

# %%
f1_score(y_test, y_pred_lrc, average=None)
# Out:
# array([0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.13333333, 0.        , 0.        ,
#        0.31578947, 0.        , 0.        , 0.        , 0.        ,
#        0.14285714])

# %%
roc_lrc=roc_auc_score(y_test, lrClassifier.predict_proba(x_test)[:, 1])
fpr_lrc, tpr_lrc, thresholds_lrc=roc_curve(y_test, lrClassifier.predict_proba(x_test)[:, 1])
plt.plot(fpr_lrc, tpr_lrc, linewidth=2, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# %%
precisions_lrc, recalls_lrc, thresholds_lrc=precision_recall_curve(y_test, lrClassifier.predict(x_test))
plt.plot(recalls_lrc, precisions_lrc, label='Precision/Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision') 
plt.show()

# %%
f1_score(y_test, y_pred_knn, average=None)

# %%
roc_knn=roc_auc_score(y_test, knnClassifier.predict_proba(x_test)[:, 1])
fpr_knn, tpr_knn, thresholds_knn=roc_curve(y_test, knnClassifier.predict_proba(x_test)[:, 1])
plt.plot(fpr_knn, tpr_knn, linewidth=2, label='ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

# %%
precisions_knn, recalls_knn, thresholds_knn=precision_recall_curve(y_test, knnClassifier.predict(x_test))
plt.plot(recalls_knn, precisions_knn, label='Precision/Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision') 
plt.show()
